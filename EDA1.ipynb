# %%
import requests
import json
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %% [markdown]
# Step 1. Get the data from API and make a dataframe

# %%
# Make request to an URL
response = requests.get('http://localhost:8080/medish_centrum_randstad/api/netlify?page=1')

# %%
file_contents= response.json()  #dictionary
print(type(file_contents))
print(len(file_contents))
# Out:
# <class 'dict'>
# 6

# %%
life_df = pd.DataFrame.from_dict(file_contents['data']) #all the needed info was condensed into one data column called 'data'
display(life_df.head())
display(life_df.shape)
# Out:
#    genetic  length  mass  exercise  smoking  alcohol  sugar  lifespan
# 0     84.0   180.0  90.0       2.0      9.0      1.0      2        86
# 1     84.0   204.0  79.0       3.0      2.0      7.0      3       100
# 2     84.0   174.0  74.0       3.0     20.0      3.0      2        87
# 3     84.0   187.0  78.0       2.0      6.0      5.0      3        91
# 4     84.0   187.0  89.0       2.0     12.0      0.0      2        83
# (8192, 8)

# %%
life_df.head()
# Out:
#    genetic  length  mass  exercise  smoking  alcohol  sugar  lifespan
# 0     84.0   180.0  90.0       2.0      9.0      1.0      2        86
# 1     84.0   204.0  79.0       3.0      2.0      7.0      3       100
# 2     84.0   174.0  74.0       3.0     20.0      3.0      2        87
# 3     84.0   187.0  78.0       2.0      6.0      5.0      3        91
# 4     84.0   187.0  89.0       2.0     12.0      0.0      2        83

# %%
life_df.tail()
# Out:
#       genetic  length  mass  exercise  smoking  alcohol  sugar  lifespan
# 8187     82.0   185.0  67.0       3.0     11.0      8.0      2        90
# 8188     82.0   183.0  72.0       2.0      1.0      5.0      4        88
# 8189     83.0   192.0  92.0       1.0     22.0      2.0      4        62
# 8190     81.0   175.0  60.0       3.0     13.0      7.0      2        93
# 8191     83.0   204.0  76.0       3.0      8.0      8.0      1        96

# %%
life_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8192 entries, 0 to 8191
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   genetic   8191 non-null   float64
#  1   length    8190 non-null   float64
#  2   mass      8191 non-null   float64
#  3   exercise  8191 non-null   float64
#  4   smoking   8191 non-null   float64
#  5   alcohol   8191 non-null   float64
#  6   sugar     8192 non-null   int64
#  7   lifespan  8192 non-null   int64
# dtypes: float64(6), int64(2)
# memory usage: 512.1 KB

# %%
life_df.describe()
# Out:
#            genetic       length         mass     exercise      smoking  \
# count  8191.000000  8190.000000  8191.000000  8191.000000  8191.000000
# mean     79.967770   183.642735    79.794286     1.617141     9.773776
# std       1.634992    12.600441    12.076801     0.830975     6.967164
# min      76.000000   154.000000    60.000000     0.000000     0.000000
# 25%      79.000000   174.000000    70.000000     1.000000     3.000000
# 50%      80.000000   183.000000    79.000000     1.000000    10.000000
# 75%      81.000000   193.000000    88.000000     2.000000    16.000000
# max      84.000000   214.000000   112.000000     4.000000    22.000000
#
#            alcohol        sugar     lifespan
# count  8191.000000  8192.000000  8192.000000
# mean      5.748260     2.423340    76.096069
# std       2.664489     0.950095    10.918167
# min       0.000000     1.000000    40.000000
# 25%       4.000000     2.000000    68.000000
# 50%       6.000000     2.000000    76.000000
# 75%       8.000000     3.000000    83.000000
# max      10.000000     5.000000   113.000000

# %% [markdown]
# Step 2. Check the missing data and decide what to keep

# %%
analysis_df = life_df.copy()
analysis_df.isnull().sum()
#any missing values?
# Out:
# genetic     1
# length      2
# mass        1
# exercise    1
# smoking     1
# alcohol     1
# sugar       0
# lifespan    0
# dtype: int64

# %%
analysis_df = analysis_df.set_index('lifespan')
analysis_df = analysis_df.sort_index()
display(analysis_df.head())
# Out:
#           genetic  length   mass  exercise  smoking  alcohol  sugar
# lifespan
# 40           80.0   158.0   96.0       0.0     19.0      8.0      4
# 44           78.0   180.0   95.0       0.0     22.0      9.0      2
# 44           79.0   178.0   93.0       0.0     22.0      5.0      4
# 44           76.0   181.0  104.0       1.0     14.0      9.0      4
# 45           78.0   170.0   81.0       1.0     21.0      8.0      5

# %%
analysis_df.duplicated().sum()
# Out:
# 3

# %%
#take look into missing values in mass
temp = (analysis_df
        .loc[(analysis_df['mass']
              .isnull())]
              .copy()
)
display(temp)
# Out:
#           genetic  length  mass  exercise  smoking  alcohol  sugar
# lifespan
# 89           78.0   176.0   NaN       3.0      3.0      3.0      4

# %%
temp1 = (analysis_df
        .loc[(analysis_df['length']
              .isnull())]
              .copy()
)
display(temp1)
#look at the missed value. I decide to drop this data because there are no substitute.
# Out:
#           genetic  length  mass  exercise  smoking  alcohol  sugar
# lifespan
# 74           80.0     NaN  90.0       2.0      7.0      7.0      3
# 82           79.0     NaN  75.0       2.0      0.0      6.0      3

# %% [markdown]
# Missing mass value is in lenth 176.0. Fill in the value using standized data.
# (source: https://www.topendsports.com/testing/BMI-table.htm)
#
# Delete other missing data's

# %%
average_bmi_176 = (62.0+77.4)/2
analysis_df.loc[(analysis_df['mass'].isnull()),'mass']=average_bmi_176
tempdf = analysis_df.query('lifespan == 89')
#check if still null values
print(tempdf['mass'].isnull().sum())
# Out:
# 0

# %% [markdown]
# Step 3. Define BMI and Exploratory Data Analysis

# %%
analysis_df['BMI'] = analysis_df['mass']/(analysis_df['length']/100)**2
display(analysis_df.head())
# Out:
#           genetic  length   mass  exercise  smoking  alcohol  sugar        BMI
# lifespan
# 40           80.0   158.0   96.0       0.0     19.0      8.0      4  38.455376
# 44           78.0   180.0   95.0       0.0     22.0      9.0      2  29.320988
# 44           79.0   178.0   93.0       0.0     22.0      5.0      4  29.352355
# 44           76.0   181.0  104.0       1.0     14.0      9.0      4  31.745063
# 45           78.0   170.0   81.0       1.0     21.0      8.0      5  28.027682

# %%
analysis_df['BMI'].value_counts().head(5)
# Out:
# 19.576333    15
# 24.655910    15
# 23.629490    14
# 28.692653    14
# 22.014014    14
# Name: BMI, dtype: int64

# %%
#Why is it missing? Is it random?
#Impute or delete?
analysis_df = analysis_df.dropna()
analysis_df.head()
# Out:
#           genetic  length   mass  exercise  smoking  alcohol  sugar        BMI
# lifespan
# 40           80.0   158.0   96.0       0.0     19.0      8.0      4  38.455376
# 44           78.0   180.0   95.0       0.0     22.0      9.0      2  29.320988
# 44           79.0   178.0   93.0       0.0     22.0      5.0      4  29.352355
# 44           76.0   181.0  104.0       1.0     14.0      9.0      4  31.745063
# 45           78.0   170.0   81.0       1.0     21.0      8.0      5  28.027682

# %%
#got any outliers?
sns.boxplot(x=analysis_df['BMI'])
# Out:
# <AxesSubplot: xlabel='BMI'>

# %%
analysis_df[analysis_df['BMI'] > 35]
#Keep the outliers since obesity is an important factor.
# Out:
#           genetic  length   mass  exercise  smoking  alcohol  sugar        BMI
# lifespan
# 40           80.0   158.0   96.0       0.0     19.0      8.0      4  38.455376
# 46           79.0   158.0   89.0       1.0     22.0      9.0      3  35.651338
# 48           80.0   169.0  111.0       1.0     19.0      9.0      3  38.864185
# 48           80.0   154.0   98.0       0.0     20.0      6.0      1  41.322314
# 48           81.0   165.0  108.0       0.0     14.0      8.0      3  39.669421
# ...           ...     ...    ...       ...      ...      ...    ...        ...
# 88           84.0   170.0  106.0       2.0      1.0      5.0      1  36.678201
# 89           81.0   155.0   97.0       3.0      1.0      8.0      2  40.374610
# 89           80.0   160.0  100.0       3.0      1.0      4.0      3  39.062500
# 92           81.0   167.0  110.0       3.0      1.0      7.0      1  39.442074
# 96           82.0   167.0  110.0       4.0     11.0      1.0      1  39.442074
#
# [179 rows x 8 columns]

# %%
sns.boxplot(x=analysis_df['exercise'])
# Out:
# <AxesSubplot: xlabel='exercise'>

# %%
analysis_df[analysis_df['exercise'] > 3.8]
# Out:
#           genetic  length   mass  exercise  smoking  alcohol  sugar  \
# lifespan
# 73           76.0   171.0   99.0       4.0     21.0      8.0      3
# 74           80.0   154.0   92.0       4.0     19.0      9.0      3
# 81           81.0   187.0  101.0       4.0     22.0      9.0      2
# 81           81.0   187.0   68.0       4.0     22.0      9.0      4
# 81           81.0   165.0   90.0       4.0     22.0      7.0      2
# ...           ...     ...    ...       ...      ...      ...    ...
# 108          79.0   210.0   69.0       4.0      0.0      9.0      2
# 110          80.0   200.0   83.0       4.0      0.0      5.0      1
# 110          80.0   198.0   64.0       4.0      3.0      4.0      2
# 112          79.0   192.0   76.0       4.0      0.0      2.0      1
# 113          83.0   183.0   61.0       4.0      0.0      5.0      1
#
#                 BMI   bmi_category
# lifespan
# 73        33.856571        obese_1
# 74        38.792376        obese_2
# 81        28.882725    over_weight
# 81        19.445795  normal_weight
# 81        33.057851        obese_1
# ...             ...            ...
# 108       15.646259   under_weight
# 110       20.750000  normal_weight
# 110       16.324865   under_weight
# 112       20.616319  normal_weight
# 113       18.214936   under_weight
#
# [86 rows x 9 columns]

# %%
ax = analysis_df['BMI'].plot(kind='hist',bins=20,title='Histogram Plot')
ax.set_xlabel('Body Mass Index, BMI (kg/m^2)')
# Out:
# Text(0.5, 0, 'Body Mass Index, BMI (kg/m^2)')

# %%
fig, ax = plt.subplots()

#ax1 = analysis_df['BMI'].plot(kind='kde', title='KDE Plot')

ax2 = sns.kdeplot(analysis_df['BMI'], fill=True, bw_method=1)
ax2.set_xlabel('Body Mass Index, BMI (kg/m^2)')
# Out:
# Text(0.5, 0, 'Body Mass Index, BMI (kg/m^2)')

# %%
temp = analysis_df.reset_index().copy()
display(temp)
# Out:
#       lifespan  genetic  length   mass  exercise  smoking  alcohol  sugar  \
# 0           40     80.0   158.0   96.0       0.0     19.0      8.0      4
# 1           44     78.0   180.0   95.0       0.0     22.0      9.0      2
# 2           44     79.0   178.0   93.0       0.0     22.0      5.0      4
# 3           44     76.0   181.0  104.0       1.0     14.0      9.0      4
# 4           45     78.0   170.0   81.0       1.0     21.0      8.0      5
# ...        ...      ...     ...    ...       ...      ...      ...    ...
# 8181       110     80.0   200.0   83.0       4.0      0.0      5.0      1
# 8182       110     80.0   198.0   64.0       4.0      3.0      4.0      2
# 8183       111     80.0   196.0   66.0       3.0      0.0      2.0      2
# 8184       112     79.0   192.0   76.0       4.0      0.0      2.0      1
# 8185       113     83.0   183.0   61.0       4.0      0.0      5.0      1
#
#             BMI
# 0     38.455376
# 1     29.320988
# 2     29.352355
# 3     31.745063
# 4     28.027682
# ...         ...
# 8181  20.750000
# 8182  16.324865
# 8183  17.180342
# 8184  20.616319
# 8185  18.214936
#
# [8186 rows x 9 columns]

# %%
ax = temp.plot(kind='scatter', y='lifespan', x='BMI', title='BMI vs Lifespan')

# %%
sns.scatterplot(data=temp, x='BMI',y='lifespan', hue='smoking')
# Out:
# <AxesSubplot: xlabel='BMI', ylabel='lifespan'>

# %%
sns.pairplot(data=temp,vars=['BMI','lifespan','smoking'], hue='exercise')

# %%
df_corr = temp[['genetic',
      'length', 'mass', 
      'exercise', 'smoking',
       'alcohol', 'sugar', 'BMI','lifespan']].dropna().corr()
df_corr.style.background_gradient(cmap='RdBu')
# Out:
# <style type="text/css">
# #T_7954a_row0_col0, #T_7954a_row1_col1, #T_7954a_row2_col2, #T_7954a_row3_col3, #T_7954a_row4_col4, #T_7954a_row5_col5, #T_7954a_row6_col6, #T_7954a_row7_col7, #T_7954a_row8_col8 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_7954a_row0_col1 {
#   background-color: #fdd9c4;
#   color: #000000;
# }
# #T_7954a_row0_col2 {
#   background-color: #c6413e;
#   color: #f1f1f1;
# }
# #T_7954a_row0_col3, #T_7954a_row2_col3, #T_7954a_row5_col3, #T_7954a_row7_col3 {
#   background-color: #730421;
#   color: #f1f1f1;
# }
# #T_7954a_row0_col4, #T_7954a_row1_col4, #T_7954a_row3_col4 {
#   background-color: #f7b99c;
#   color: #000000;
# }
# #T_7954a_row0_col5, #T_7954a_row1_col2, #T_7954a_row3_col5, #T_7954a_row4_col2 {
#   background-color: #cf5246;
#   color: #f1f1f1;
# }
# #T_7954a_row0_col6 {
#   background-color: #d7634f;
#   color: #f1f1f1;
# }
# #T_7954a_row0_col7, #T_7954a_row3_col1, #T_7954a_row4_col1, #T_7954a_row5_col7 {
#   background-color: #fcd7c2;
#   color: #000000;
# }
# #T_7954a_row0_col8 {
#   background-color: #fae7dc;
#   color: #000000;
# }
# #T_7954a_row1_col0 {
#   background-color: #6d0220;
#   color: #f1f1f1;
# }
# #T_7954a_row1_col3, #T_7954a_row6_col0, #T_7954a_row6_col3 {
#   background-color: #6a011f;
#   color: #f1f1f1;
# }
# #T_7954a_row1_col5 {
#   background-color: #d05548;
#   color: #f1f1f1;
# }
# #T_7954a_row1_col6 {
#   background-color: #d55d4c;
#   color: #f1f1f1;
# }
# #T_7954a_row1_col7, #T_7954a_row2_col0, #T_7954a_row4_col0, #T_7954a_row4_col3, #T_7954a_row4_col8, #T_7954a_row7_col0, #T_7954a_row7_col1, #T_7954a_row8_col2, #T_7954a_row8_col4, #T_7954a_row8_col5, #T_7954a_row8_col6 {
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# #T_7954a_row1_col8 {
#   background-color: #f9ede5;
#   color: #000000;
# }
# #T_7954a_row2_col1, #T_7954a_row4_col7, #T_7954a_row6_col7 {
#   background-color: #fdddcb;
#   color: #000000;
# }
# #T_7954a_row2_col4 {
#   background-color: #f9c2a7;
#   color: #000000;
# }
# #T_7954a_row2_col5, #T_7954a_row4_col5 {
#   background-color: #ce4f45;
#   color: #f1f1f1;
# }
# #T_7954a_row2_col6, #T_7954a_row2_col8 {
#   background-color: #da6853;
#   color: #f1f1f1;
# }
# #T_7954a_row2_col7 {
#   background-color: #3783bb;
#   color: #f1f1f1;
# }
# #T_7954a_row3_col0, #T_7954a_row5_col0 {
#   background-color: #700320;
#   color: #f1f1f1;
# }
# #T_7954a_row3_col2, #T_7954a_row6_col8 {
#   background-color: #cb4942;
#   color: #f1f1f1;
# }
# #T_7954a_row3_col6, #T_7954a_row5_col8 {
#   background-color: #d6604d;
#   color: #f1f1f1;
# }
# #T_7954a_row3_col7, #T_7954a_row5_col1 {
#   background-color: #fddbc7;
#   color: #000000;
# }
# #T_7954a_row3_col8 {
#   background-color: #4c99c6;
#   color: #f1f1f1;
# }
# #T_7954a_row4_col6 {
#   background-color: #d86551;
#   color: #f1f1f1;
# }
# #T_7954a_row5_col2 {
#   background-color: #c94741;
#   color: #f1f1f1;
# }
# #T_7954a_row5_col4 {
#   background-color: #f8bda1;
#   color: #000000;
# }
# #T_7954a_row5_col6, #T_7954a_row7_col6 {
#   background-color: #dc6e57;
#   color: #f1f1f1;
# }
# #T_7954a_row6_col1 {
#   background-color: #fcd5bf;
#   color: #000000;
# }
# #T_7954a_row6_col2, #T_7954a_row7_col5 {
#   background-color: #cc4c44;
#   color: #f1f1f1;
# }
# #T_7954a_row6_col4 {
#   background-color: #f8bb9e;
#   color: #000000;
# }
# #T_7954a_row6_col5 {
#   background-color: #d25849;
#   color: #f1f1f1;
# }
# #T_7954a_row7_col2 {
#   background-color: #59a1ca;
#   color: #f1f1f1;
# }
# #T_7954a_row7_col4 {
#   background-color: #f9c4a9;
#   color: #000000;
# }
# #T_7954a_row7_col8, #T_7954a_row8_col0 {
#   background-color: #c84440;
#   color: #f1f1f1;
# }
# #T_7954a_row8_col1 {
#   background-color: #f5f6f7;
#   color: #000000;
# }
# #T_7954a_row8_col3 {
#   background-color: #9dcbe1;
#   color: #000000;
# }
# #T_7954a_row8_col7 {
#   background-color: #df765e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7954a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7954a_level0_col0" class="col_heading level0 col0" >genetic</th>
#       <th id="T_7954a_level0_col1" class="col_heading level0 col1" >length</th>
#       <th id="T_7954a_level0_col2" class="col_heading level0 col2" >mass</th>
#       <th id="T_7954a_level0_col3" class="col_heading level0 col3" >exercise</th>
#       <th id="T_7954a_level0_col4" class="col_heading level0 col4" >smoking</th>
#       <th id="T_7954a_level0_col5" class="col_heading level0 col5" >alcohol</th>
#       <th id="T_7954a_level0_col6" class="col_heading level0 col6" >sugar</th>
#       <th id="T_7954a_level0_col7" class="col_heading level0 col7" >BMI</th>
#       <th id="T_7954a_level0_col8" class="col_heading level0 col8" >lifespan</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7954a_level0_row0" class="row_heading level0 row0" >genetic</th>
#       <td id="T_7954a_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_7954a_row0_col1" class="data row0 col1" >-0.002061</td>
#       <td id="T_7954a_row0_col2" class="data row0 col2" >-0.009935</td>
#       <td id="T_7954a_row0_col3" class="data row0 col3" >0.004218</td>
#       <td id="T_7954a_row0_col4" class="data row0 col4" >-0.010887</td>
#       <td id="T_7954a_row0_col5" class="data row0 col5" >0.003763</td>
#       <td id="T_7954a_row0_col6" class="data row0 col6" >-0.006869</td>
#       <td id="T_7954a_row0_col7" class="data row0 col7" >-0.008239</td>
#       <td id="T_7954a_row0_col8" class="data row0 col8" >0.151944</td>
#     </tr>
#     <tr>
#       <th id="T_7954a_level0_row1" class="row_heading level0 row1" >length</th>
#       <td id="T_7954a_row1_col0" class="data row1 col0" >-0.002061</td>
#       <td id="T_7954a_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_7954a_row1_col2" class="data row1 col2" >0.017811</td>
#       <td id="T_7954a_row1_col3" class="data row1 col3" >-0.007374</td>
#       <td id="T_7954a_row1_col4" class="data row1 col4" >-0.008893</td>
#       <td id="T_7954a_row1_col5" class="data row1 col5" >0.006826</td>
#       <td id="T_7954a_row1_col6" class="data row1 col6" >-0.015382</td>
#       <td id="T_7954a_row1_col7" class="data row1 col7" >-0.661735</td>
#       <td id="T_7954a_row1_col8" class="data row1 col8" >0.179804</td>
#     </tr>
#     <tr>
#       <th id="T_7954a_level0_row2" class="row_heading level0 row2" >mass</th>
#       <td id="T_7954a_row2_col0" class="data row2 col0" >-0.009935</td>
#       <td id="T_7954a_row2_col1" class="data row2 col1" >0.017811</td>
#       <td id="T_7954a_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_7954a_row2_col3" class="data row2 col3" >0.004133</td>
#       <td id="T_7954a_row2_col4" class="data row2 col4" >0.016246</td>
#       <td id="T_7954a_row2_col5" class="data row2 col5" >-0.002077</td>
#       <td id="T_7954a_row2_col6" class="data row2 col6" >0.006609</td>
#       <td id="T_7954a_row2_col7" class="data row2 col7" >0.726119</td>
#       <td id="T_7954a_row2_col8" class="data row2 col8" >-0.201582</td>
#     </tr>
#     <tr>
#       <th id="T_7954a_level0_row3" class="row_heading level0 row3" >exercise</th>
#       <td id="T_7954a_row3_col0" class="data row3 col0" >0.004218</td>
#       <td id="T_7954a_row3_col1" class="data row3 col1" >-0.007374</td>
#       <td id="T_7954a_row3_col2" class="data row3 col2" >0.004133</td>
#       <td id="T_7954a_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_7954a_row3_col4" class="data row3 col4" >-0.012952</td>
#       <td id="T_7954a_row3_col5" class="data row3 col5" >0.005744</td>
#       <td id="T_7954a_row3_col6" class="data row3 col6" >-0.008909</td>
#       <td id="T_7954a_row3_col7" class="data row3 col7" >0.005216</td>
#       <td id="T_7954a_row3_col8" class="data row3 col8" >0.677432</td>
#     </tr>
#     <tr>
#       <th id="T_7954a_level0_row4" class="row_heading level0 row4" >smoking</th>
#       <td id="T_7954a_row4_col0" class="data row4 col0" >-0.010887</td>
#       <td id="T_7954a_row4_col1" class="data row4 col1" >-0.008893</td>
#       <td id="T_7954a_row4_col2" class="data row4 col2" >0.016246</td>
#       <td id="T_7954a_row4_col3" class="data row4 col3" >-0.012952</td>
#       <td id="T_7954a_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_7954a_row4_col5" class="data row4 col5" >0.001535</td>
#       <td id="T_7954a_row4_col6" class="data row4 col6" >-0.001565</td>

# %%
sns.heatmap(df_corr,annot=True)
# Out:
# <AxesSubplot: >

# %%
plt.figure(figsize=(10,5))
c= analysis_df.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
#De informatie van theorie les.
# Out:
#            genetic    length      mass  exercise   smoking   alcohol  \
# genetic   1.000000 -0.002061 -0.009935  0.004218 -0.010887  0.003763
# length   -0.002061  1.000000  0.017811 -0.007374 -0.008893  0.006826
# mass     -0.009935  0.017811  1.000000  0.004133  0.016246 -0.002077
# exercise  0.004218 -0.007374  0.004133  1.000000 -0.012952  0.005744
# smoking  -0.010887 -0.008893  0.016246 -0.012952  1.000000  0.001535
# alcohol   0.003763  0.006826 -0.002077  0.005744  0.001535  1.000000
# sugar    -0.006869 -0.015382  0.006609 -0.008909 -0.001565  0.013651
# BMI      -0.008239 -0.661735  0.726119  0.005216  0.019533 -0.006216
#
#              sugar       BMI
# genetic  -0.006869 -0.008239
# length   -0.015382 -0.661735
# mass      0.006609  0.726119
# exercise -0.008909  0.005216
# smoking  -0.001565  0.019533
# alcohol   0.013651 -0.006216
# sugar     1.000000  0.014166
# BMI       0.014166  1.000000

# %%
def bmi_category(bmi):
    if bmi > 40:
        return 'obese_3'
    elif bmi > 35:
        return 'obese_2'
    elif bmi > 30:
        return 'obese_1'
    elif bmi > 25:
        return 'over_weight'
    elif bmi >= 18.5:
        return 'normal_weight'
    else:
        return 'under_weight'

# %%
import numpy as np
bmi_category = [0, 18.5, 25, 30, 35, 40, np.inf]
analysis_df['bmi_category']= pd.cut(analysis_df['BMI'], bins=bmi_category, labels=['under_weight','normal_weight','over_weight','obese_1','obese_2','obese_3'] )
analysis_df.head(12)
# Out:
#           genetic  length   mass  exercise  smoking  alcohol  sugar  \
# lifespan
# 40           80.0   158.0   96.0       0.0     19.0      8.0      4
# 44           78.0   180.0   95.0       0.0     22.0      9.0      2
# 44           79.0   178.0   93.0       0.0     22.0      5.0      4
# 44           76.0   181.0  104.0       1.0     14.0      9.0      4
# 45           78.0   170.0   81.0       1.0     21.0      8.0      5
# 45           80.0   174.0   80.0       1.0     22.0     10.0      4
# 46           79.0   158.0   89.0       1.0     22.0      9.0      3
# 46           80.0   163.0   83.0       0.0     16.0      9.0      3
# 46           77.0   164.0   93.0       1.0     12.0      8.0      4
# 47           79.0   182.0  107.0       0.0     18.0      8.0      3
# 47           77.0   183.0   93.0       0.0     18.0      9.0      2
# 47           79.0   172.0   89.0       1.0     21.0      7.0      5
#
#                 BMI bmi_category
# lifespan
# 40        38.455376      obese_2
# 44        29.320988  over_weight
# 44        29.352355  over_weight
# 44        31.745063      obese_1
# 45        28.027682  over_weight
# 45        26.423570  over_weight
# 46        35.651338      obese_2
# 46        31.239414      obese_1
# 46        34.577632      obese_1
# 47        32.302862      obese_1
# 47        27.770313  over_weight
# 47        30.083829      obese_1

# %%
analysis_df.groupby('bmi_category')['sugar', 'exercise'].mean()
# Out:
# C:\Users\jiyoo\AppData\Local\Temp\ipykernel_12412\3594314296.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   analysis_df.groupby('bmi_category')['sugar', 'exercise'].mean()
#                   sugar  exercise
# bmi_category
# under_weight   2.374637  1.590513
# normal_weight  2.424416  1.631278
# over_weight    2.443519  1.599074
# obese_1        2.422980  1.654040
# obese_2        2.474026  1.500000
# obese_3        2.080000  1.560000

# %%
analysis_df.columns
# Out:
# Index(['genetic', 'length', 'mass', 'exercise', 'smoking', 'alcohol', 'sugar',
#        'BMI', 'bmi_category'],
#       dtype='object')
